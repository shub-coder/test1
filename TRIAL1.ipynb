# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # NOW WE WILL READ OUR DATAFRAME.

# %%
df=pd.read_csv('Life Expectancy Data.csv')
df
# Out:
#           Country  Year  ... Income composition of resources  Schooling
# 0     Afghanistan  2015  ...                           0.479       10.1
# 1     Afghanistan  2014  ...                           0.476       10.0
# 2     Afghanistan  2013  ...                           0.470        9.9
# 3     Afghanistan  2012  ...                           0.463        9.8
# 4     Afghanistan  2011  ...                           0.454        9.5
# ...           ...   ...  ...                             ...        ...
# 2933     Zimbabwe  2004  ...                           0.407        9.2
# 2934     Zimbabwe  2003  ...                           0.418        9.5
# 2935     Zimbabwe  2002  ...                           0.427       10.0
# 2936     Zimbabwe  2001  ...                           0.427        9.8
# 2937     Zimbabwe  2000  ...                           0.434        9.8
#
# [2938 rows x 22 columns]

# %%
plt.figure(figsize=(10, 5))
plt.subplot(121)
df.Status.value_counts().plot(kind='bar')
plt.title('Count of Rows by Country Status')
plt.xlabel('Country Status')
plt.ylabel('Count of Rows')
plt.xticks(rotation=0)
# Out:
# (array([0, 1]), <a list of 2 Text major ticklabel objects>)

# %% [markdown]
# # WE WILL ANALYZE THE DATA OF INDIA TO SEE HOW OTHER FACTORS AFFECT THE LIFE EXPECTANCY IN INDIA.

# %%
India_data=df.loc[1188:1201]
India_data
# Out:
#      Country  Year  ... Income composition of resources  Schooling
# 1188   India  2013  ...                           0.599       11.5
# 1189   India  2012  ...                           0.590       11.3
# 1190   India  2011  ...                           0.580       10.8
# 1191   India  2010  ...                           0.569       10.4
# 1192   India  2009  ...                           0.563       10.5
# 1193   India  2008  ...                           0.556       10.2
# 1194   India  2007  ...                           0.546        9.9
# 1195   India  2006  ...                           0.536        9.7
# 1196   India  2005  ...                           0.526        9.4
# 1197   India  2004  ...                           0.518        9.2
# 1198   India  2003  ...                           0.505        8.6
# 1199   India  2002  ...                           0.499        8.4
# 1200   India  2001  ...                           0.494        8.3
# 1201   India  2000  ...                           0.489        8.3
#
# [14 rows x 22 columns]

# %% [markdown]
# WE WILL CHECK FOR THE NULL VALUES IN OUR DATASET.

# %%
India_data.isnull()
# Out:
#       Country   Year  ...  Income composition of resources  Schooling
# 1188    False  False  ...                            False      False
# 1189    False  False  ...                            False      False
# 1190    False  False  ...                            False      False
# 1191    False  False  ...                            False      False
# 1192    False  False  ...                            False      False
# 1193    False  False  ...                            False      False
# 1194    False  False  ...                            False      False
# 1195    False  False  ...                            False      False
# 1196    False  False  ...                            False      False
# 1197    False  False  ...                            False      False
# 1198    False  False  ...                            False      False
# 1199    False  False  ...                            False      False
# 1200    False  False  ...                            False      False
# 1201    False  False  ...                            False      False
#
# [14 rows x 22 columns]

# %%
India_data.isnull().sum()
# Out:
# Country                            0
# Year                               0
# Status                             0
# Life expectancy                    0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        4
# Measles                            0
#  BMI                               0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
#  HIV/AIDS                          0
# GDP                                0
# Population                         0
#  thinness  1-19 years              0
#  thinness 5-9 years                0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %%
India_data.rename(columns={'Hepatitis B':'HepB'},inplace=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
India_data
# Out:
#      Country  Year  ... Income composition of resources  Schooling
# 1188   India  2013  ...                           0.599       11.5
# 1189   India  2012  ...                           0.590       11.3
# 1190   India  2011  ...                           0.580       10.8
# 1191   India  2010  ...                           0.569       10.4
# 1192   India  2009  ...                           0.563       10.5
# 1193   India  2008  ...                           0.556       10.2
# 1194   India  2007  ...                           0.546        9.9
# 1195   India  2006  ...                           0.536        9.7
# 1196   India  2005  ...                           0.526        9.4
# 1197   India  2004  ...                           0.518        9.2
# 1198   India  2003  ...                           0.505        8.6
# 1199   India  2002  ...                           0.499        8.4
# 1200   India  2001  ...                           0.494        8.3
# 1201   India  2000  ...                           0.489        8.3
#
# [14 rows x 22 columns]

# %%
India_data.HepB=India_data.HepB.fillna(India_data.HepB.mean())
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
A=India_data

# %%
A
# Out:
#      Country  Year  ... Income composition of resources  Schooling
# 1188   India  2013  ...                           0.599       11.5
# 1189   India  2012  ...                           0.590       11.3
# 1190   India  2011  ...                           0.580       10.8
# 1191   India  2010  ...                           0.569       10.4
# 1192   India  2009  ...                           0.563       10.5
# 1193   India  2008  ...                           0.556       10.2
# 1194   India  2007  ...                           0.546        9.9
# 1195   India  2006  ...                           0.536        9.7
# 1196   India  2005  ...                           0.526        9.4
# 1197   India  2004  ...                           0.518        9.2
# 1198   India  2003  ...                           0.505        8.6
# 1199   India  2002  ...                           0.499        8.4
# 1200   India  2001  ...                           0.494        8.3
# 1201   India  2000  ...                           0.489        8.3
#
# [14 rows x 22 columns]

# %%
A1=A[['Country','Year','Life expectancy ','Adult Mortality','infant deaths']]

# %%
A1
# Out:
#      Country  Year  Life expectancy   Adult Mortality  infant deaths
# 1188   India  2013              67.6            187.0           1000
# 1189   India  2012              67.3             19.0           1100
# 1190   India  2011              66.8            193.0           1100
# 1191   India  2010              66.4            196.0           1200
# 1192   India  2009              66.0              2.0           1300
# 1193   India  2008              65.5             23.0           1300
# 1194   India  2007              65.2             26.0           1400
# 1195   India  2006              64.8             28.0           1500
# 1196   India  2005              64.4            211.0           1500
# 1197   India  2004              64.0            214.0           1600
# 1198   India  2003              63.7            216.0           1700
# 1199   India  2002              63.3            219.0           1700
# 1200   India  2001              62.9            222.0           1800
# 1201   India  2000              62.5            224.0           1800

# %% [markdown]
# #OUTLIER DETECTION:

# %%
sns.boxplot(A1['Life expectancy '])

# %%
sns.boxplot(A1['Adult Mortality'])

# %%
sns.boxplot(A1['infant deaths'])

# %%
A1.describe()
# Out:
#             Year  Life expectancy   Adult Mortality  infant deaths
# count    14.0000         14.000000        14.000000      14.000000
# mean   2006.5000         65.028571       141.428571    1428.571429
# std       4.1833          1.644772        95.011509     270.124107
# min    2000.0000         62.500000         2.000000    1000.000000
# 25%    2003.2500         63.775000        26.500000    1225.000000
# 50%    2006.5000         65.000000       194.500000    1450.000000
# 75%    2009.7500         66.300000       215.500000    1675.000000
# max    2013.0000         67.600000       224.000000    1800.000000

# %%
corr1=A1.corr()
corr1
# Out:
#                       Year  Life expectancy   Adult Mortality  infant deaths
# Year              1.000000          0.999469        -0.456164      -0.993864
# Life expectancy   0.999469          1.000000        -0.448759      -0.992317
# Adult Mortality  -0.456164         -0.448759         1.000000       0.416398
# infant deaths    -0.993864         -0.992317         0.416398       1.000000

# %%
plt.figure(figsize=(12,6))
sns.heatmap(corr1,annot=True)
plt.title('CORRELATION HEATMAP',size=20)
# Out:
# Text(0.5, 1.0, 'CORRELATION HEATMAP')

# %% [markdown]
# FROM ABOVE CORRELATIONAL MATRIX AND HEATMAP WE CAN SEE THAT INFANT DEATHS AND ADULT MORTALITY RATES ARE NEGATIVELY CORRELATED WITH LIFE EXPECATNCY.

# %%
plt.figure(figsize=(14,6))

sns.barplot(A1['Year'],A1['Life expectancy '])
plt.title('YEAR WISE LIFE EXPECTANCY IN INDIA',size=20)
plt.legend()
plt.grid(color='grey',axis='y')
plt.tight_layout()
# Out:
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(14,6))

sns.barplot(A1['Year'],A1['Adult Mortality'])
plt.grid(color='grey',axis='y')
plt.title('YEAR WISE ADULT MORTALITY RATE IN INDIA',size=20)
plt.tight_layout()

# %%
plt.figure(figsize=(14,6))
sns.barplot(A1['Year'],A1['infant deaths'])
plt.title('YEAR WISE INFANT DEATHS PER 1000 POPULATION',size=20)
plt.grid(color='grey',axis='y')
plt.tight_layout()

# %% [markdown]
# LET'S SEE HOW OTHER FACTORS AFFECT THE LIFE EXPECTANCY.

# %%
A
# Out:
#      Country  Year  ... Income composition of resources  Schooling
# 1188   India  2013  ...                           0.599       11.5
# 1189   India  2012  ...                           0.590       11.3
# 1190   India  2011  ...                           0.580       10.8
# 1191   India  2010  ...                           0.569       10.4
# 1192   India  2009  ...                           0.563       10.5
# 1193   India  2008  ...                           0.556       10.2
# 1194   India  2007  ...                           0.546        9.9
# 1195   India  2006  ...                           0.536        9.7
# 1196   India  2005  ...                           0.526        9.4
# 1197   India  2004  ...                           0.518        9.2
# 1198   India  2003  ...                           0.505        8.6
# 1199   India  2002  ...                           0.499        8.4
# 1200   India  2001  ...                           0.494        8.3
# 1201   India  2000  ...                           0.489        8.3
#
# [14 rows x 22 columns]

# %%
A.describe()
# Out:
#             Year  Life expectancy   ...  Income composition of resources  Schooling
# count    14.0000         14.000000  ...                        14.000000  14.000000
# mean   2006.5000         65.028571  ...                         0.540714   9.750000
# std       4.1833          1.644772  ...                         0.036747   1.093864
# min    2000.0000         62.500000  ...                         0.489000   8.300000
# 25%    2003.2500         63.775000  ...                         0.508250   8.750000
# 50%    2006.5000         65.000000  ...                         0.541000   9.800000
# 75%    2009.7500         66.300000  ...                         0.567500  10.475000
# max    2013.0000         67.600000  ...                         0.599000  11.500000
#
# [8 rows x 20 columns]

# %%
corr=A.corr()
corr
# Out:
#                                      Year  ...  Schooling
# Year                             1.000000  ...   0.990965
# Life expectancy                  0.999469  ...   0.989780
# Adult Mortality                 -0.456164  ...  -0.504187
# infant deaths                   -0.993864  ...  -0.986664
# Alcohol                          0.956249  ...   0.940552
# percentage expenditure           0.684947  ...   0.663079
# HepB                             0.366975  ...   0.349710
# Measles                         -0.560559  ...  -0.548033
#  BMI                             0.998502  ...   0.990768
# under-five deaths               -0.997546  ...  -0.987012
# Polio                            0.974674  ...   0.969299
# Total expenditure                0.239330  ...   0.231208
# Diphtheria                       0.383327  ...   0.363064
#  HIV/AIDS                       -0.832050  ...  -0.813187
# GDP                              0.659939  ...   0.630898
# Population                      -0.108983  ...  -0.067982
#  thinness  1-19 years           -0.961351  ...  -0.944798
#  thinness 5-9 years             -0.994433  ...  -0.989207
# Income composition of resources  0.997782  ...   0.995872
# Schooling                        0.990965  ...   1.000000
#
# [20 rows x 20 columns]

# %%
plt.figure(figsize=(30,15))
sns.heatmap(corr,annot=True)
plt.title('CORRELATION HEATMAP',size=20)
# Out:
# Text(0.5, 1.0, 'CORRELATION HEATMAP')

# %% [markdown]
# FROM ABOVE CORRELATIONAL MATRIX WE CAN SEE THAT THE POLIO IMMUNIZATION AND HEPATITIS B IMMUNIZATION IS NEGATIVELY CORRELATED WITH INFANT DEATHS FEATURE.

# %% [markdown]
# # NOW WE WILL SEE HOW SCHOOLING IMPACTS LIFESPAN OF HUMANS IN INDIA??

# %%
plt.figure(figsize=(14,6))
plt.plot(A['Life expectancy '],A['Schooling'],marker='o')
plt.grid(color='grey')
plt.xlabel('LIFE EXPECTANCY')
plt.ylabel('NO. OF SCHOOLING YEARS')
plt.title('LINE GRAPH')
# Out:
# Text(0.5, 1.0, 'LINE GRAPH')

# %%
plt.figure(figsize=(16,6))
sns.barplot(A['Year'],A['Schooling'])
plt.grid(color='grey',axis='y')
plt.title('NO. OF SCHOOLING YEARS(YEAR WISE)',size=20)
plt.tight_layout()
